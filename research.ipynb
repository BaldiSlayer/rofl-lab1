# %% [markdown]
# ### Гипотезы
# 1. Убрать ненужные слова по типу: расскажи, докажи, из, ...
#
#     Есть два пути: выбрать опорные слова из определений и оставить только их или собрать служебные и второстепенные слова и выкинуть служебные
# 2. На каком языке лучше (хотим русский)
# 3. Дообучить русскую нейронку (недавно вышла Т-pro)

# %% [markdown]
# ## качаю нужные библиотеки

# %%
# !pip install pymorphy2
# Out:
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting dawg-python>=0.7.1 (from pymorphy2)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4 (from pymorphy2)
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting docopt>=0.6 (from pymorphy2)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 2.6 MB/s eta 0:00:00
# Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 53.2 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=f4c8a345c1b227573ae4c4d2cb8c923154a517be4a90d1fde17221369e36d7a1
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %%
# !pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)
# Downloading pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 37.0 MB/s eta 0:00:00
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20240706

# %%
# !pip install 'pdfminer.six[image]'
# Out:
# Requirement already satisfied: pdfminer.six[image] in /usr/local/lib/python3.10/dist-packages (20240706)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six[image]) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six[image]) (43.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from pdfminer.six[image]) (11.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six[image]) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six[image]) (2.22)

# %% [markdown]
# ## всякие импорты

# %%
import re # регулярки
import nltk # для стоп-слов
from nltk.tokenize import sent_tokenize # для токенизации
from nltk.tokenize import RegexpTokenizer # разбиваем на слова
from nltk.corpus import stopwords # убираем стоп слова
import pymorphy2 # для лемантизации
from collections import Counter # подсчёт частых
from gensim.models.phrases import Phrases, Phraser # дли биграмм

from gensim.models.word2vec import Word2Vec

from pdfminer.high_level import extract_text # pdf в текст

from google.colab import drive # подключение к диску

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
stopwords_ru = stopwords.words('russian')
tokenizer = RegexpTokenizer('\w+')
morph = pymorphy2.MorphAnalyzer()

# %% [markdown]
# ## начинаем работу с текстами

# %% [markdown]
# ### книга

# %%
# лекции за 2023 год + материалы итмо + книга хопкрофта на русском
all_texts = []

for i in range(1, 68):
    t = extract_text(f"/content/drive/MyDrive/texts/{i}.pdf")
    # глазами зацепилась за не оч хорошие переносы, поэтому фикс
    t = t.replace('-\n', '')
    all_texts.append(t)

# %% [markdown]
# ## код

# %% [markdown]
# ### какие-то мои функции

# %%
# подсчёт метрики k
def my_metrics(user, db, clean_dict=None, trash_dict=None):
    user = make_clean(user)
    db = make_clean(db)

    user = get_words_only(user)
    db = get_words_only(db)

    if clean_dict is not None:
        user = [w for w in user if w in my_dict]
        db = [w for w in db if w in my_dict]

    if trash_dict is not None:
        user = [w for w in user if w not in trash_dict]
        db = [w for w in db if w not in trash_dict]

    print(user)
    print(db)

    in_both = list(set(user) & set(db))

    return len(in_both) / (len(db) + epsilon)

# %%
# берём только слова из предложений
def get_words_only(sentences_tokenize):
    words = [item for sent in sentences_tokenize for item in sent]

    return words

# %%
def make_clean(text):
    # чистим текст
    text = text.lower()
    text = re.sub('\n|\t|\r', ' ', text)
    # преобразуем в предложения
    sentences = sent_tokenize(text)
    # бъём предложения на слова
    sentences_tokenize = [tokenizer.tokenize(item) for item in sentences]
    # убираем стоп слова
    sentences_tokenize = [[item for item in sent if (item not in stopwords_ru and re.match('^[а-я]*$', item))] for sent in sentences_tokenize]
    # лемантизируем слова
    sentences_tokenize = [[morph.normal_forms(item)[0] for item in sent] for sent in sentences_tokenize]

    return sentences_tokenize

# %%
# словарь популярных слов
def get_dict_words(sentences_tokenize):
    words = [item for sent in  sentences_tokenize for item in sent]
    word_dict = Counter(words)
    common = word_dict.most_common()

    return common

# %%
# полезные слова = часто встречаем их
def get_useful(common):
    my_dict = {}

    for i, j in common:
        if i != 'ε' and len(i) > 2 and re.match('^[а-я]*$', i):
            my_dict[i] = j

    return my_dict

# %% [markdown]
# ### смотрим на текст

# %%
epsilon = 0.001

all_sentences = []
all_words = []

my_dict = {}

# мусорные конструкции
trash_dict = ['че', 'доказать', 'рассказать', 'ваш', 'привести', 'сделать', 'описать', 'дать', 'что']

# %%
for text in all_texts:
    t = make_clean(text)
    all_sentences = all_sentences + t

    # частые слова
    common = get_dict_words(t)
    all_words += [i for (i, j) in common]
    # «полезные» слова
    useful_dict = get_useful(common)

    new_dict = dict(list(my_dict.items()) + list(useful_dict.items()))
    my_dict = new_dict.copy()

# %% [markdown]
# ### предобработка перед w2v

# %%
bigram = Phrases(all_sentences)
bigram_transformer = Phraser(bigram)

# генератор текстов с биграммами
def bigram_generator():
    for text in all_sentences:
        yield bigram_transformer[[word for word in text]]

# %%
trigram = Phrases(bigram_generator())
trigram_transformer = Phraser(trigram)

def trigram_generator():
    for text in all_sentences:
        yield trigram_transformer[bigram_transformer[[word for word in text]]]

# %%
words = [i for i in trigram_generator()]
words
# Out:
# [['основной_определение',
#   'связанный',
#   'строка',
#   'содержание',
#   'базовый',
#   'определение',
#   'отношение',
#   'строка',
#   'формальный',
#   'язык',
#   'операция',
#   'язык',
#   'пример',
#   'гомоморфизм',
#   'язык',
#   'пример',
#   'смотреть'],
#  ['также_источник_информация',
#   'базовый',
#   'определение',
#   'определение',
#   'символ',
#   'англ'],
#  ['объект',
#   'иметь',
#   'собственный',
#   'содержание',
#   'уникальный',
#   'читаемый',
#   'форма'],
#  ['определение', 'алфавит', 'англ'],
#  ['конечный', 'непустой', 'множество', 'символ'],
#  ['условиться', 'обозначать', 'алфавит', 'большой', 'греческий', 'буква'],
#  ['наиболее',
#   'часто',
#   'использоваться',
#   'следующий',
#   'алфавит',
#   'нотный',
#   'знак',
#   'бинарный',
#   'двоичный',
#   'алфавит'],
#  ['множество', 'строчный_буква', 'английский', 'алфавит'],
#  ['алфавит', 'цифра'],
#  ['алфавит', 'лежать', 'основа', 'азбука', 'морзе'],
#  ['определение', 'слово', 'англ'],
#  ['цепочка',
#   'конечный',
#   'последовательность',
#   'символ',
#   'некоторый',
#   'алфавит'],
#  ['определение', 'длина', 'цепочка', 'англ'],
#  ['число', 'символ', 'цепочка'],
#  ['длина', 'некоторый', 'цепочка', 'обозначать'],
#  ['обычно', 'определение', 'множество', 'цепочка', 'длина', 'алфавит'],
#  ['множество', 'цепочка', 'алфавит'],
#  ['определение',
#   'определение',
#   'пусть',
#   'который',
#   'последовательно',
#   'записать',
#   'цепочка'],
#  [],
#  ['обозначать', 'конкатенация', 'англ'],
#  ['цепочка', 'определение', 'пустой', 'цепочка', 'англ'],
#  ['цепочка', 'содержать', 'один', 'символ'],
#  ['цепочка', 'обозначать'],
#  ['рассматривать', 'цепочка', 'любой', 'алфавит'],
#  ['любой',
#   'строка',
#   'верно',
#   'множество',
#   'строка',
#   'операция',
#   'конкатенация',
#   'нейтральный_элемент',
#   'пустой_строка',
#   'образовать',
#   'свободный',
#   'моноид'],
#  ['отношение', 'строка', 'определение', 'префикс', 'англ'],
#  ['строка', 'строка'],
#  ['пусть', 'префикс'],
#  ['определение', 'суффикс', 'англ'],
#  ['строка', 'строка'],
#  ['пусть', 'суффикс'],
#  ['определение', 'бордер', 'англ'],
#  ['строка', 'строка'],
#  ['пусть', 'бордер'],
#  ['определение', 'символ', 'строка', 'находиться', 'ой', 'позиция'],
#  ['пусть'],
#  ['определение', 'период', 'англ'],
#  ['строка', 'число'],
#  ['пусть', 'период', 'строка'],
#  ['утверждение',
#   'пусть',
#   'известный',
#   'строка',
#   'период',
#   'восстановить',
#   'строка'],
#  ['определение', 'период', 'строка', 'следовать'],
#  [],
#  ['такой_образ',
#   'определение',
#   'строка',
#   'период',
#   'называться',
#   'сильнопериодический'],
#  ['строка', 'являться', 'сильнопериодический', 'период'],
#  ['определение', 'подстрока', 'англ'],
#  ['некоторый',
#   'непустой',
#   'подпоследовательность',
#   'подряд',
#   'идти',
#   'символ',
#   'строка'],
#  ['пусть', 'подстрока', 'строка'],
#  ['определение', 'тандемный_повтор', 'англ'],
#  ['называться', 'непустой', 'строка', 'вид'],
#  ['определение', 'палиндром', 'англ'],
#  ['называться', 'строка', 'вид', 'любой', 'символ'],
#  ['определение',
#   'развернуть',
#   'строка',
#   'строка',
#   'лексикографически',
#   'маленький',
#   'строка',
#   'префикс'],
#  ['строка', 'являться', 'префикс'],
#  ['строка'],
#  ['формальный', 'язык', 'определение', 'язык', 'англ'],
#  ['алфавит', 'формальный', 'англ'],
#  ['подчеркнуть', 'отличие', 'язык', 'привычный', 'смысл'],
#  ['некоторый', 'подмножество'],
#  ['такой',
#   'язык',
#   'называть',
#   'отметить',
#   'язык',
#   'известно',
#   'являться',
#   'надмножество'],
#  ['обязательно',
#   'должный',
#   'содержать',
#   'цепочка',
#   'который',
#   'входить',
#   'символ'],
#  ['поэтому',
#   'являться',
#   'язык',
#   'утверждать',
#   'это',
#   'язык',
#   'любой',
#   'алфавит',
#   'операция',
#   'язык',
#   'пусть',
#   'язык'],
#  ['они', 'определить', 'следующий', 'операция'],
#  ['теоретико', 'множественный', 'операция', 'дополнение'],
#  [],
#  ['объединение',
#   'пересечение',
#   'разность',
#   'конкатенация',
#   'конкатенация',
#   'обратный',
#   'язык'],
#  ['замыкание_клини', 'степень', 'язык', 'слово'],
#  [],
#  ['конкатенация',
#   'обратный_гомоморфизм',
#   'пример',
#   'язык',
#   'состоять',
#   'последовательность',
#   'нуль',
#   'последовательность',
#   'единица',
#   'пустой',
#   'аналогично',
#   'предыдущий',
#   'содержать',
#   'пустой_строка'],
#  ['содержать', 'двоичный', 'вектор', 'пустой_строка'],
#  ['язык', 'десятичный', 'представление', 'простой', 'число', 'язык', 'строка'],
#  ['начинаться', 'тройка'],
#  [],
#  ['содержать',
#   'десятичный',
#   'представление',
#   'простой',
#   'число',
#   'гомоморфизм',
#   'язык',
#   'определение',
#   'пусть_дать',
#   'алфавит'],
#  ['гомоморфизм',
#   'называться',
#   'такой',
#   'отображение',
#   'сохранять',
#   'пустой_строка',
#   'сохранять',
#   'конкатенация',
#   'определение',
#   'образ',
#   'язык',
#   'называться',
#   'язык',
#   'заметить',
#   'гомоморфизм',
#   'гомоморфизм',
#   'моноид'],
#  ['называть',
#   'прямой',
#   'гомоморфизм',
#   'определение',
#   'прообраз',
#   'язык',
#   'гомоморфизм',
#   'называться',
#   'язык',
#   'заметить',
#   'гомоморфизм',
#   'моноид'],
#  ['гомоморфизм',
#   'называть',
#   'обратный',
#   'пример',
#   'тривиальный',
#   'гомоморфизм',
#   'обнулять',
#   'тождественный',
#   'гомоморфизм',
#   'цепочка',
#   'функция',
#   'подставлять',
#   'некоторый',
#   'строка',
#   'вместо',
#   'каждый',
#   'символ'],
#  ['формально',
#   'задать',
#   'отображение',
#   'действовать',
#   'каждый',
#   'символ',
#   'строка',
#   'язык',
#   'следующий_образ'],
#  [],
#  [],
#  ['цепочка',
#   'солнечный',
#   'язык',
#   'детский',
#   'игра',
#   'каждый',
#   'гласный',
#   'слово',
#   'добавлять',
#   'буква',
#   'гласный',
#   'представить_вид',
#   'гомоморфизм',
#   'язык',
#   'согласный',
#   'символ',
#   'отображаться',
#   'сам',
#   'гласный',
#   'символ'],
#  ['регулярный',
#   'язык',
#   'замкнутый_относительно',
#   'гомоморфизм',
#   'гомоморфизм',
#   'цепочка',
#   'функция',
#   'переходить'],
#  [],
#  [],
#  ['циклический',
#   'гомоморфизм',
#   'зафиксировать',
#   'порядок',
#   'символ',
#   'алфавит',
#   'быть',
#   'отображать',
#   'каждый',
#   'символ',
#   'следующий',
#   'последний',
#   'первый'],
#  ['обратный_гомоморфизм', 'отображение', 'каждый', 'символ', 'предыдущий'],
#  ['смотреть'],
#  ['также',
#   'период',
#   'бордер',
#   'связь',
#   'слово',
#   'фибоначча',
#   'слово',
#   'туэ',
#   'морс',
#   'регулярный',
#   'язык',
#   'определение',
#   'эквивалентность',
#   'источник_информация_википедия',
#   'формальный',
#   'язык',
#   'википедия',
#   'звезда',
#   'клини',
#   'гасфилд',
#   'далее',
#   'строка',
#   'дерево',
#   'последовательность',
#   'алгоритм',
#   'информатика',
#   'вычислительный',
#   'биология'],
#  ['быть_изд'],
#  [],
#  [],
#  [],
#  ['хопкрофт_далее_мотвани_р',
#   'ульман_далее_введение_теория',
#   'автомат',
#   'язык',
#   'вычисление_быть_изд'],
#  ['пер'],
#  ['англ'],
#  ['м_издательский_дом_вильямс'],
#  [],
#  ['источник'],
#  ['этот_страница', 'последний_отредактировать_сентябрь'],
#  ['регулярный',
#   'язык',
#   'определение',
#   'эквивалентность',
#   'регулярный',
#   'язык',
#   'определение',
#   'эквивалентность',
#   'определение',
#   'множество',
#   'регулярный',
#   'язык',
#   'англ'],
#  ['множество',
#   'который',
#   'получить',
#   'язык',
#   'каждый',
#   'который',
#   'содержать',
#   'единственный',
#   'слово',
#   'пустой',
#   'язык',
#   'помощь',
#   'последовательный',
#   'применение',
#   'операция',
#   'объединение_конкатенация',
#   'замыкание_клини',
#   'никакой_другой',
#   'алфавит',
#   'определимый',
#   'регулярный',
#   'язык',
#   'нулевой',
#   'уровень',
#   'регулярный',
#   'язык',
#   'ненулевой',
#   'уровень',
#   'определимый',
#   'рекуррентный',
#   'соотношение'],
#  [],
#  [],
#  ['определение', 'регулярный_выражение', 'англ'],
#  ['алфавит', 'порождение', 'язык'],
#  ['определяться',
#   'рекурсивный',
#   'следующий_образ',
#   'способ',
#   'регулярный_выражение',
#   'задавать',
#   'являться',
#   'регулярный_выражение',
#   'задавать',
#   'язык',
#   'являться',
#   'регулярный_выражение',
#   'задавать',
#   'язык',
#   'один',
#   'слово',
#   'любой',
#   'слово',
#   'являться',
#   'регулярный_выражение',
#   'задавать',
#   'язык',
#   'один',
#   'пустой_строка',
#   'регулярный_выражение',
#   'задавать',
#   'являться',
#   'регулярный_выражение',
#   'задавать',
#   'язык',
#   'задавать',
#   'операция',
#   'указать',
#   'порядок',
#   'возрастание',
#   'приоритет',
#   'скобка',
#   'повышать',
#   'приоритет',
#   'аналогично',
#   'арифметический_выражение'],
#  ['являться', 'регулярный_выражение', 'задавать', 'язык', 'пустой', 'язык'],
#  ['соответственно', 'регулярный_выражение', 'соответственно'],
#  [],
#  [],
#  [],
#  ['утверждение',
#   'построение',
#   'очевидный',
#   'множество',
#   'язык',
#   'порождать',
#   'регулярный_выражение',
#   'совпадать',
#   'множество',
#   'регулярный',
#   'язык'],
#  ['определение', 'пусть', 'задать', 'алфавит'],
#  ['множество', 'быть_называть', 'надрегулярный_множество', 'алфавит'],
#  [],
#  [],
#  ['множество',
#   'регулярный',
#   'язык',
#   'алфавит',
#   'пересечение',
#   'надрегулярный_множество',
#   'это',
#   'алфавит'],
#  ['называться',
#   'теорема',
#   'класс',
#   'язык',
#   'одинаковый',
#   'алфавит',
#   'совпадать'],
#  ['доказательство', 'доказать'],
#  ['определение', 'доказать', 'индукция', 'любой'],
#  [],
#  ['показать', 'любой', 'надрегулярный_множество'],
#  ['база'],
#  ['определение', 'надрегулярный_множество'],
#  ['переход', 'известно', 'доказать'],
#  ['определение',
#   'надрегулярный_множество',
#   'любой',
#   'вспоминать',
#   'определение',
#   'предположение_индукция',
#   'получать',
#   'верный',
#   'утверждение'],
#  [],
#  [],
#  ['любой', 'надрегулярный_множество', 'получать'],
#  ['доказать',
#   'надрегулярный_множество',
#   'являться',
#   'надрегулярный_множество'],
#  ['проверить', 'выполняться', 'свойство', 'выполнить', 'определение'],
#  ['следовать', 'рассмотреть'],
#  ['найтись_такой', 'индекс'],
#  ['определение'],
#  ['получать'],
#  ['следовательно', 'второе', 'свойство', 'также', 'выполнить'],
#  ['значит', 'множество', 'надрегулярный_множество'],
#  [],
#  ['являться', 'пересечение', 'надрегулярный', 'смотреть'],
#  ['также',
#   'детерминированный_конечный_автомат',
#   'источник_информация_википедия',
#   'регулярный',
#   'язык',
#   'википедия',
#   'регулярный_выражение',
#   'источник'],
#  ['этот_страница', 'последний_отредактировать_сентябрь'],
#  ['детерминированный_конечный_автомат',
#   'определение',
#   'детерминированный_конечный_автомат',
#   'дка',
#   'англ'],
#  ['набор', 'пять', 'элемент', 'состояние', 'англ'],
#  ['допускать', 'состояние', 'англ'],
#  ['начальный', 'стартовый_состояние', 'англ'],
#  ['функция_переход', 'англ'],
#  [],
#  ['множество', 'алфавит', 'англ'],
#  ['множество',
#   'содержание',
#   'процесс_допуск',
#   'способ',
#   'представление',
#   'диаграмма',
#   'переход',
#   'таблица',
#   'переход',
#   'автоматный_язык',
#   'изоморфизм',
#   'два',
#   'автомат',
#   'алгоритм',
#   'псевдокод',
#   'смотреть'],
#  ['также_источник_информация', 'процесс_допуск'],
#  ['автомат', 'считывать', 'символ', 'очередь'],
#  ['считывание',
#   'изначально',
#   'автомат',
#   'находиться',
#   'стартовый_состояние',
#   'автомат',
#   'переходить',
#   'состояние',
#   'очередной',
#   'символ',
#   'продолжаться',
#   'тот_пора',
#   'пока',
#   'достигнуть',
#   'конец',
#   'входной',
#   'слово'],
#  ['текущий', 'состояние', 'автомат'],
#  ['процесс', 'определение', 'быть_говорить', 'автомат', 'допускать', 'англ'],
#  ['слово',
#   'окончание',
#   'описать_выше',
#   'процесс',
#   'автомат',
#   'оказаться',
#   'допускать',
#   'состояние'],
#  ['замечание'],
#  ['момент',
#   'текущий',
#   'состояние',
#   'переход',
#   'считать',
#   'символ',
#   'быть_считать',
#   'автомат',
#   'допускать',
#   'данный',
#   'слово'],
#  ['реализация',
#   'вместо',
#   'отдельный',
#   'рассмотрение',
#   'данный_случай',
#   'удобно',
#   'вводить',
#   'фиктивный',
#   'нетерминальный',
#   'дьявольский',
#   'вершина',
#   'также',
#   'тупиковый',
#   'состояние',
#   'сток',
#   'который',
#   'любой',
#   'переход',
#   'вести',
#   'сам',
#   'заменить',
#   'несуществующий',
#   'переход',
#   'переход',
#   'дьявольский',
#   'вершина'],
#  ['способ',
#   'представление',
#   'диаграмма',
#   'переход',
#   'диаграмма',
#   'переход',
#   'граф',
#   'вершина',
#   'который',
#   'соответствовать',
#   'состояние',
#   'автомат',
#   'переход',
#   'состояние'],
#  ['нетерминальный',
#   'состояние',
#   'терминальный',
#   'состояние',
#   'стрелка',
#   'указывать',
#   'начальный_состояние'],
#  ['пример', 'описание', 'автомат', 'поиск', 'образец', 'текст', 'строка'],
#  ['автомат',
#   'принимать',
#   'непустой',
#   'строка',
#   'чередоваться',
#   'символ',
#   'дьявольский',
#   'вершина'],
#  ['автомат',
#   'принимать',
#   'непустой',
#   'строка',
#   'чередоваться',
#   'символ',
#   'дьявольский',
#   'вершина'],
#  ['давать', 'табличный', 'представление', 'функция'],
#  ['таблица',
#   'переход',
#   'таблица',
#   'переход',
#   'функция_переход',
#   'представить',
#   'таблица',
#   'автоматный_язык',
#   'определение',
#   'мгновенный',
#   'описание',
#   'конфигурация',
#   'англ'],
#  ['пара', 'остаться', 'символ'],
#  ['текущий', 'состояние', 'быть_говорить', 'конфигурация', 'выводить'],
#  ['быть_говорить', 'конфигурация', 'выводить', 'шаг', 'конечный_число', 'шаг'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['лемма'],
#  ['доказательство'],
#  ['определение', 'множество'],
#  ['называться', 'язык', 'автомат', 'англ'],
#  ['иначе',
#   'говорить',
#   'язык',
#   'автомат',
#   'являться',
#   'множество',
#   'допускать',
#   'слово'],
#  ['произвольный',
#   'язык',
#   'являться_автоматный',
#   'существовать',
#   'дка',
#   'допускать',
#   'тот',
#   'тот',
#   'слово',
#   'который',
#   'принадлежать',
#   'язык'],
#  ['определение',
#   'множество',
#   'язык',
#   'дка',
#   'образовать',
#   'множество',
#   'автоматный_язык'],
#  ['изоморфизм',
#   'два',
#   'автомат',
#   'определение',
#   'автомат',
#   'называться',
#   'изоморфный',
#   'англ'],
#  ['существовать',
#   'биекция',
#   'вершина',
#   'такой',
#   'сохраняться',
#   'переход',
#   'терминальный',
#   'состояние',
#   'соответствовать',
#   'терминальный',
#   'начальный',
#   'начальный'],
#  ['задача', 'задать', 'детерминированный_конечный_автомат'],
#  ['определить', 'изоморфный', 'друг_друг'],
#  ['гарантироваться', 'состояние', 'автомат', 'достижимый'],
#  ['алгоритм',
#   'определение',
#   'следовать',
#   'автомат',
#   'изоморфный',
#   'состояние',
#   'занумеровать',
#   'один',
#   'способ',
#   'вершина',
#   'разный',
#   'автомат',
#   'одинаковый',
#   'номер',
#   'быть',
#   'равный',
#   'каждый',
#   'этот',
#   'два',
#   'состояние',
#   'существовать',
#   'переход',
#   'какой',
#   'состояние',
#   'такой',
#   'номер',
#   'переход',
#   'буква',
#   'друг',
#   'состояние'],
#  ['поэтому',
#   'мочь',
#   'зафиксировать',
#   'какой',
#   'нумерация',
#   'например',
#   'порядок',
#   'обход_глубина',
#   'символ',
#   'лексикографический_порядок',
#   'просто',
#   'проверить',
#   'состояние',
#   'одинаковый',
#   'номер',
#   'равенство'],
#  ['состояние',
#   'быть',
#   'равный',
#   'автомат',
#   'быть',
#   'равный',
#   'наш',
#   'случай',
#   'следовать',
#   'изоморфизм',
#   'два',
#   'автомат'],
#  ['асимптотик',
#   'алгоритм',
#   'совпадать',
#   'асимптотика',
#   'обход_глубина',
#   'суммарный',
#   'число',
#   'вершина',
#   'автомат',
#   'суммарный',
#   'число',
#   'ребро'],
#  ['псевдокод', 'второй', 'автомат'],
#  ['множество',
#   'пара',
#   'массив',
#   'каждый',
#   'состояние',
#   'первый',
#   'автомат',
#   'соответствовать',
#   'найти',
#   'состояние',
#   'заметить',
#   'достаточно',
#   'один',
#   'массив',
#   'автомат',
#   'один',
#   'вершина',
#   'дьявольский',
#   'другой',
#   'смотреть'],
#  ['также',
#   'недетерминированный_конечный',
#   'автомат',
#   'автомат',
#   'кнут',
#   'моррис',
#   'пратта',
#   'суффиксный',
#   'автомат',
#   'алгоритм',
#   'ахо',
#   'корасик',
#   'теорема_клини',
#   'совпадение_класс',
#   'автоматный',
#   'регулярный',
#   'язык',
#   'источник_информация_хопкрофт_далее',
#   'мотвани_р',
#   'ульман_далее_введение_теория',
#   'автомат',
#   'язык',
#   'вычисление_быть_изд'],
#  ['пер'],
#  ['англ'],
#  ['м_издательский_дом_вильямс'],
#  [],
#  [],
#  [],
#  [],
#  ['источник_этот_страница_последний', 'отредактировать_сентябрь'],
#  ['прямой_произведение',
#   'дка',
#   'определение',
#   'прямой_произведение',
#   'два',
#   'дка',
#   'дка',
#   'называться',
#   'содержание',
#   'пример',
#   'применение',
#   'объединение',
#   'дка',
#   'разность',
#   'дка',
#   'смотреть'],
#  ['также_источник_информация',
#   'пример',
#   'взять',
#   'автомат',
#   'согласно',
#   'определение'],
#  [],
#  [],
#  [],
#  [],
#  ['утверждение',
#   'построить',
#   'прямой_произведение',
#   'автомат',
#   'автомат',
#   'пересечение'],
#  ['который', 'допускать', 'автомат', 'взять', 'слово', 'автомат'],
#  ['построить',
#   'список',
#   'пара',
#   'автомат',
#   'состояние',
#   'процесс_допуск',
#   'слово',
#   'автомат'],
#  ['выписать',
#   'состояние',
#   'порядок',
#   'допуск',
#   'слово',
#   'состояние',
#   'проходимый',
#   'допуск',
#   'слово',
#   'автомат'],
#  ['данный',
#   'список',
#   'являться',
#   'список',
#   'сохраняться',
#   'стартовый_состояние',
#   'переход',
#   'верный',
#   'сохраняться',
#   'терминальный',
#   'состояние',
#   'следовательно',
#   'автомат',
#   'допускать',
#   'слово',
#   'который',
#   'допускать',
#   'автомат',
#   'автомат'],
#  ['взять',
#   'слово',
#   'состояние',
#   'следовательно',
#   'который',
#   'допускать',
#   'автомат'],
#  ['автомат',
#   'нетерминальный',
#   'применение',
#   'изменить',
#   'конструкция',
#   'получить',
#   'автомат',
#   'допускать',
#   'разность',
#   'объединение',
#   'два',
#   'язык'],
#  ['объединение',
#   'дка',
#   'необходимо',
#   'разрешать',
#   'любой',
#   'цепочка',
#   'удовлетворять',
#   'первый',
#   'второй',
#   'автомат'],
#  ['сделать',
#   'терминальный',
#   'следующий',
#   'вершина',
#   'требование',
#   'попасть',
#   'какой_либо',
#   'состояние',
#   'второй',
#   'автомат',
#   'соответственно'],
#  ['цепочка', 'удовлетворять', 'первый'],
#  ['получить',
#   'автомат',
#   'удовлетворять',
#   'наш',
#   'разность',
#   'дка',
#   'рассмотреть',
#   'автомат',
#   'состояние',
#   'инвертировать',
#   'автомат',
#   'опустить',
#   'дьявольский',
#   'состояние',
#   'необходимо',
#   'добавить',
#   'сделать',
#   'терминальный'],
#  ['очевидный',
#   'допускать',
#   'тот',
#   'тот',
#   'слово',
#   'который',
#   'допускать',
#   'автомат',
#   'который',
#   'терминальный',
#   'нетерминальный',
#   'автомат',
#   'значит',
#   'язык'],
#  ['заметить', 'регулярный', 'язык', 'регулярный'],
#  ['следовательно',
#   'построить',
#   'пересечение',
#   'два',
#   'автомат',
#   'предварительно',
#   'инвертировать',
#   'второй',
#   'терминальный',
#   'нетерминальный',
#   'состояние'],
#  ['заметить',
#   'меняться',
#   'набор',
#   'терминальный',
#   'вершина',
#   'следовательно',
#   'итоговый',
#   'конструкция',
#   'произведение',
#   'дка',
#   'сделать',
#   'терминальный',
#   'следующий',
#   'вершина'],
#  ['такой_образ',
#   'получить',
#   'альтернативный',
#   'доказательство',
#   'замкнутость_регулярный',
#   'язык',
#   'относительно',
#   'теоретикомножественный',
#   'операция'],
#  ['смотреть'],
#  ['также',
#   'детерминированный_конечный_автомат',
#   'замкнутость_регулярный',
#   'язык',
#   'относительно_различный_операция',
#   'источник_информация_хопкрофт_далее',
#   'мотвани_р',
#   'ульман_далее_введение_теория',
#   'автомат',
#   'язык',
#   'вычисление_быть_изд'],
#  ['пер'],
#  ['англ'],
#  ['м_издательский_дом_вильямс'],
#  [],
#  ['источник_этот_страница_последний', 'отредактировать_сентябрь'],
#  ['преобразование',
#   'регулярный_выражение',
#   'дка',
#   'содержание',
#   'преобразование',
#   'регулярный_выражение',
#   'дка',
#   'преобразование',
#   'регулярный_выражение',
#   'нка',
#   'пример',
#   'преобразование',
#   'дка',
#   'регулярный_выражение',
#   'алгебраический',
#   'метод',
#   'бжозовский',
#   'пример',
#   'смотреть'],
#  ['также_источник_информация',
#   'преобразование',
#   'регулярный_выражение',
#   'дка',
#   'преобразовать',
#   'регулярный_выражение',
#   'дка',
#   'нужно',
#   'преобразовать',
#   'регулярный_выражение',
#   'нка',
#   'переход'],
#  ['устранить', 'переход'],
#  ['построить', 'нка', 'эквивалентный_дка'],
#  ['преобразование',
#   'регулярный_выражение',
#   'нка',
#   'преобразование',
#   'проводиться',
#   'структурный',
#   'индукция',
#   'выражение',
#   'регулярный_выражение'],
#  ['необходимо',
#   'рекурсивный',
#   'спуститься',
#   'вглубь',
#   'язык',
#   'автомат',
#   'распознавать',
#   'представить_рис'],
#  ['это', 'базис'],
#  ['следовать', 'рекурсивный', 'определение', 'дойти', 'нулевой', 'уровень'],
#  ['рис'],
#  ['б',
#   'далее',
#   'строиться',
#   'выражение',
#   'пока',
#   'следующий_образ',
#   'выражение',
#   'иметь_вид',
#   'представить_рис'],
#  [],
#  ['предполагать',
#   'значит',
#   'возможно',
#   'построить',
#   'построить',
#   'некоторый',
#   'выражение'],
#  ['соответствовать', 'автомат', 'выражение', 'иметь_вид', 'построить'],
#  ['автомат', 'конкатенация', 'представить_рис'],
#  ['б'],
#  ['предполагать',
#   'значит',
#   'возможно',
#   'построить',
#   'строиться',
#   'тот',
#   'алгоритм',
#   'выражение',
#   'иметь_вид'],
#  ['использовать', 'автомат', 'представить_рис'],
#  [],
#  ['строиться', 'тот', 'алгоритм', 'рис'],
#  ['индукционный_переход',
#   'преобразование',
#   'регулярный_выражение',
#   'нка',
#   'пример',
#   'задача',
#   'преобразовать',
#   'регулярный_выражение',
#   'дка'],
#  ['регулярный_выражение',
#   'автомат',
#   'преобразовать',
#   'регулярный_выражение',
#   'сначала',
#   'автомат'],
#  ['это', 'выражение', 'иметь_вид', 'нка'],
#  ['построить'],
#  ['далее', 'считать', 'это', 'подвыражение', 'вид'],
#  ['строить', 'выражение', 'выражение', 'иметь_вид', 'иметь_вид'],
#  ['удалить', 'переход', 'согласно', 'алгоритм', 'статья', 'получить', 'нка'],
#  ['преобразовать', 'нка', 'дка', 'алгоритм_томпсон'],
#  ['преобразование',
#   'дка',
#   'регулярный_выражение',
#   'алгебраический',
#   'метод',
#   'бжозовский',
#   'преобразование',
#   'дка',
#   'регулярный_выражение',
#   'создаваться',
#   'система',
#   'регулярный_выражение',
#   'каждый',
#   'состояние',
#   'дка',
#   'затем',
#   'решаться',
#   'регулярный_выражение',
#   'построение',
#   'уравнение',
#   'происходить',
#   'следующий_образ',
#   'каждый',
#   'состояние',
#   'связанный',
#   'терминальный',
#   'состояние',
#   'уравнение',
#   'являться'],
#  ['объединение', 'переход', 'ведущий', 'это', 'состояние'],
#  ['переход', 'терминальный', 'состояние', 'обозначаться', 'добавляться'],
#  ['это', 'приводить', 'система_уравнение', 'вид'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['переход',
#   'исключение',
#   'случай',
#   'неизвестный',
#   'появляться',
#   'правый',
#   'левый_часть',
#   'уравнение'],
#  ['воспользоваться', 'теорема', 'арден'],
#  ['система',
#   'решить',
#   'помощь',
#   'простой',
#   'подстановка',
#   'уравнение',
#   'вид',
#   'иметь_решение'],
#  ['пример',
#   'задача',
#   'построить',
#   'регулярный_выражение',
#   'удовлетворять',
#   'дать',
#   'дка'],
#  ['решение',
#   'рассмотреть',
#   'первый',
#   'терминальный',
#   'состояние',
#   'воспользоваться',
#   'теорема',
#   'арден',
#   'рассмотреть',
#   'второе',
#   'терминальный',
#   'состояние',
#   'объединить',
#   'выражение',
#   'терминальный',
#   'состояние',
#   'получить',
#   'искомое',
#   'регулярный_выражение',
#   'смотреть'],
#  ['также',
#   'регулярный',
#   'язык',
#   'определение',
#   'эквивалентность',
#   'детерминированный_конечный_автомат',
#   'построение',
#   'нка',
#   'эквивалентный_дка',
#   'алгоритм_томпсон',
#   'источник_информация',
#   'источник'],
#  ['этот_страница', 'последний_отредактировать_сентябрь'],
#  ['простой',
#   'сопоставитель',
#   'регулярный_выражение',
#   'задача',
#   'дать',
#   'регулярный_выражение',
#   'текст'],
#  ['нужно',
#   'проверить',
#   'допускать',
#   'регулярный_выражение',
#   'данный',
#   'текст'],
#  ['содержание',
#   'алгоритм',
#   'псевдокод',
#   'модификация',
#   'псевдокод',
#   'смотреть'],
#  ['также_примечание_источник_информация',
#   'алгоритм',
#   'данный',
#   'алгоритм_работать',
#   'быстрый',
#   'недетерминированный_конечный',
#   'автомат',
#   'построить',
#   'теорема_клини',
#   'регулярный_выражение',
#   'состоять',
#   'символ',
#   'любой',
#   'буквенный',
#   'символ'],
#  ['любой',
#   'символ',
#   'символ',
#   'начало',
#   'текст',
#   'символ',
#   'конец',
#   'текст',
#   'предыдущий',
#   'символ',
#   'встречаться',
#   'ноль'],
#  ['например'],
#  [],
#  ['очевидный',
#   'простой',
#   'написать',
#   'простой',
#   'сопоставитель',
#   'строить',
#   'нка'],
#  ['псевдокод',
#   'поиск',
#   'вхождение',
#   'регулярный_выражение',
#   'любой',
#   'место',
#   'текст',
#   'возвращать',
#   'первый',
#   'элемент',
#   'функция',
#   'текст'],
#  ['существовать',
#   'один',
#   'вхождение',
#   'найтись',
#   'самый_левый',
#   'самый',
#   'короткий'],
#  ['проверять',
#   'вхождение',
#   'регулярный_выражение',
#   'любой',
#   'место',
#   'предел',
#   'простой'],
#  ['логика',
#   'функция',
#   'вхождение',
#   'должный',
#   'начинаться',
#   'начало',
#   'текст'],
#  ['входить', 'текст', 'первый', 'позиция', 'текст', 'середина', 'текст'],
#  ['это',
#   'проверяться',
#   'путём',
#   'сопоставление',
#   'остаток',
#   'регулярный_выражение',
#   'текст',
#   'начинать',
#   'первый',
#   'позиция',
#   'нигде'],
#  ['первый',
#   'символ',
#   'регулярный_выражение',
#   'любой',
#   'возможный',
#   'регулярный_выражение',
#   'должный',
#   'противный_случай',
#   'регулярный_выражение',
#   'входить',
#   'текст',
#   'любой',
#   'позиция'],
#  ['это',
#   'проверяться',
#   'путём',
#   'сопоставление',
#   'регулярный_выражение',
#   'позиция',
#   'текст'],
#  ['регулярный_выражение',
#   'входить',
#   'один',
#   'раз',
#   'текст',
#   'самый_левый',
#   'вхождение',
#   'распознать'],
#  ['найтись', 'самый_левый', 'вхождение', 'текст'],
#  ['регулярный_выражение',
#   'поиск',
#   'вхождение',
#   'регулярный_выражение',
#   'начало',
#   'текст',
#   'выход',
#   'предел',
#   'строка',
#   'конец',
#   'символ'],
#  ['основный', 'часть', 'работа', 'сделать', 'текст', 'текущий', 'позиция'],
#  ['функция', 'первый', 'символ', 'текст'],
#  ['случай',
#   'успех',
#   'мочь',
#   'сравнить',
#   'следующий',
#   'символ',
#   'регулярный_выражение',
#   'следующий',
#   'символ',
#   'текст',
#   'вызвать',
#   'текущий',
#   'позиция',
#   'текст'],
#  ['который', 'сопоставлять', 'регулярный_выражение', 'рекурсивный'],
#  ['иначе',
#   'совпадение',
#   'регулярный_выражение',
#   'пытаться',
#   'сопоставить',
#   'первый',
#   'символ',
#   'регулярный_выражение',
#   'сопоставление',
#   'регулярный_выражение',
#   'вид'],
#  ['рассмотреть',
#   'возможный',
#   'случай',
#   'ход',
#   'рекурсия',
#   'регулярный_выражение',
#   'остаться',
#   'пустой',
#   'это',
#   'регулярный_выражение'],
#  ['текст',
#   'допускаться',
#   'регулярный_выражение',
#   'иметь_вид',
#   'вызываться',
#   'функция',
#   'который',
#   'пытаться',
#   'начинать',
#   'нуль',
#   'повторение',
#   'увеличивать',
#   'количество',
#   'пока',
#   'найти',
#   'сопоставить',
#   'повторение',
#   'символ',
#   'совпадение',
#   'остаться',
#   'текст'],
#  ['совпадение', 'найти', 'регулярный_выражение', 'допускать', 'текст'],
#  ['текущий',
#   'реализация',
#   'искать',
#   'краткий',
#   'совпадение',
#   'который',
#   'подходить',
#   'сопоставление',
#   'образец',
#   'нужно',
#   'быстрый',
#   'найти',
#   'совпадение'],
#  ['длинный',
#   'совпадение',
#   'интуитивно',
#   'подходить',
#   'текстовый',
#   'редактор',
#   'найти',
#   'заменить'],
#  ['большинство',
#   'современный',
#   'библиотека',
#   'работа',
#   'регулярный_выражение',
#   'предоставлять',
#   'оба',
#   'вариант'],
#  ['регулярный_выражение',
#   'это',
#   'первый',
#   'символ',
#   'текст',
#   'совпасть',
#   'первый',
#   'символ',
#   'регулярный_выражение',
#   'нужно',
#   'проверить',
#   'совпадать',
#   'следующий',
#   'символ',
#   'регулярный_выражение',
#   'следующий',
#   'символ',
#   'текст',
#   'сделать',
#   'рекурсивный',
#   'вызов',
#   'оно',
#   'допускать',
#   'текст',
#   'текст',
#   'закончиться'],
#  [],
#  ['предыдущий',
#   'попытка',
#   'найти',
#   'совпадение',
#   'провалиться',
#   'никакой',
#   'подстрока',
#   'текст',
#   'допускаться',
#   'регулярный_выражение'],
#  ['модификация',
#   'немного',
#   'изменить',
#   'функция',
#   'поиск',
#   'сам',
#   'левый',
#   'сам',
#   'длинный',
#   'вхождение',
#   'найти',
#   'максимальный',
#   'последовательность',
#   'подряд',
#   'идти',
#   'символ'],
#  ['назвать',
#   'сопоставимый',
#   'часть',
#   'текст',
#   'часть',
#   'совпасть',
#   'текст',
#   'допускаться',
#   'это',
#   'регулярный_выражение'],
#  ['иначе', 'остаток', 'регулярный_выражение'],
#  [],
#  ['допускаться',
#   'это',
#   'регулярный_выражение',
#   'иначе',
#   'убирать',
#   'символ',
#   'повторять',
#   'шаг',
#   'пусто',
#   'текст'],
#  ['псевдокод'],
#  ['смотреть'],
#  ['также',
#   'регулярный',
#   'язык',
#   'определение',
#   'эквивалентность',
#   'примечание_источник',
#   'информация_источник'],
#  ['этот_страница', 'последний_отредактировать_сентябрь'],
#  ['недетерминированный_конечный',
#   'автомат',
#   'определение',
#   'недетерминированный_конечный',
#   'автомат',
#   'нка',
#   'англ'],
#  ['функция_переход'],
#  ['начальный_состояние',
#   'автомат',
#   'такой_образ',
#   'единственный',
#   'отличие',
#   'нка',
#   'дка',
#   'существование',
#   'несколько',
#   'переход',
#   'один',
#   'символ',
#   'один',
#   'состояние'],
#  ['множество',
#   'допускать',
#   'состояние',
#   'автомат',
#   'множество',
#   'состояние',
#   'автомат',
#   'алфавит',
#   'содержание',
#   'процесс_допуск',
#   'язык',
#   'автомат',
#   'пример',
#   'алгоритм',
#   'определять',
#   'допустимость',
#   'автомат',
#   'слово',
#   'постановка',
#   'задача',
#   'алгоритм',
#   'псевдокод',
#   'смотреть'],
#  ['также_источник_информация',
#   'процесс_допуск',
#   'нка',
#   'допускать',
#   'слово',
#   'выписать',
#   'переход',
#   'путь',
#   'порядок',
#   'образовать',
#   'слово',
#   'существовать_путь',
#   'начальный_состояние',
#   'какой',
#   'терминальный',
#   'такой',
#   'буква'],
#  ['это', 'описать', 'формально'],
#  ['определение', 'мгновенный', 'описание', 'англ'],
#  ['пара'],
#  ['определимый', 'некоторый', 'операция', 'мгновенный', 'описание'],
#  ['определение_говорить', 'выводиться', 'шаг', 'англ'],
#  [],
#  ['это', 'также', 'записывать'],
#  ['определение',
#   'рефлексивный_транзитивный_замыкание',
#   'отношение',
#   'говорить',
#   'выводиться',
#   'ноль',
#   'шаг',
#   'англ'],
#  ['обозначаться'],
#  [],
#  ['определение', 'нка', 'допускать', 'англ'],
#  ['слово'],
#  ['язык',
#   'автомат',
#   'определение',
#   'множество',
#   'слово',
#   'допускать',
#   'автомат',
#   'называться',
#   'язык',
#   'нка'],
#  [],
#  ['случай', 'также', 'говорить', 'автомат', 'англ'],
#  ['язык'],
#  ['язык',
#   'нка',
#   'являться_автоматный',
#   'язык',
#   'любой',
#   'нка',
#   'построить',
#   'эквивалентный_дка',
#   'значит',
#   'вычислительный',
#   'мощность',
#   'этот',
#   'два',
#   'автомат',
#   'совпадать'],
#  ['пример',
#   'это',
#   'нка',
#   'который',
#   'распознать',
#   'язык',
#   'алфавит',
#   'четвёртый',
#   'конец',
#   'позиция',
#   'стоить',
#   'алгоритм',
#   'определять',
#   'допустимость',
#   'автомат',
#   'слово',
#   'постановка',
#   'задача',
#   'пусть',
#   'задать',
#   'нка',
#   'слово'],
#  ['требоваться', 'определить', 'допускать', 'нка', 'данный', 'слово'],
#  ['алгоритм',
#   'определимый',
#   'множество',
#   'достижимый',
#   'состояние',
#   'стартовый',
#   'слово',
#   'заметить'],
#  ['такой_образ', 'алгоритм', 'состоять', 'построить', 'слово_допускаться'],
#  ['определение'],
#  ['очевидный'],
#  ['пусть', 'построить'],
#  ['построить'],
#  ['заметить', 'научиться'],
#  ['строить',
#   'взять',
#   'быть',
#   'последовательно',
#   'вычислять',
#   'такой_образ',
#   'получить',
#   'остаться',
#   'проверить',
#   'терминальный',
#   'состояние'],
#  ['псевдокод', 'время_работа_алгоритм'],
#  ['смотреть'],
#  ['также',
#   'детерминированный_конечный_автомат',
#   'построение',
#   'нка',
#   'эквивалентный_дка',
#   'алгоритм_томпсон',
#   'источник_информация',
#   'ю',
#   'громкович',
#   'теоретический',
#   'информатика'],
#  ['введение_теория_автомат',
#   'теория',
#   'вычислимость',
#   'теория',
#   'сложность',
#   'теория',
#   'алгоритм',
#   'рандомизация',
#   'теория',
#   'связь',
#   'криптография',
#   'пер'],
#  ['немой'],
#  ['спб'],
#  ['бхвпетербург'],
#  [],
#  [],
#  [],
#  [],
#  ['источник_этот_страница_последний', 'отредактировать_сентябрь'],
#  ['построение',
#   'нка',
#   'эквивалентный_дка',
#   'алгоритм_томпсон',
#   'содержание',
#   'описание',
#   'построение',
#   'эквивалентный_дка',
#   'нка',
#   'доказательство',
#   'эквивалентность',
#   'алгоритм_томпсон',
#   'алгоритм',
#   'асимптотик',
#   'пример',
#   'смотреть'],
#  ['также_источник_информация',
#   'описание',
#   'алгоритм_томпсон',
#   'строить',
#   'нка',
#   'эквивалентный_дка',
#   'следующий_образ',
#   'начало'],
#  ['шаг',
#   'помещать',
#   'очередь',
#   'шаг',
#   'затем',
#   'пока',
#   'очередь',
#   'пустой',
#   'выполнять',
#   'следующий',
#   'действие',
#   'множество',
#   'состоять',
#   'стартовый_вершина'],
#  ['посмотреть',
#   'какой',
#   'состояние',
#   'вести',
#   'переход',
#   'символ',
#   'доставать',
#   'очередь',
#   'множество',
#   'назвать',
#   'получить',
#   'множество',
#   'состояние',
#   'положим',
#   'очередь',
#   'каждый',
#   'такой',
#   'множество',
#   'итоговый',
#   'дка',
#   'отдельный',
#   'вершина',
#   'который',
#   'быть',
#   'вести',
#   'переход',
#   'соответствовать',
#   'символ'],
#  ['множество', 'множество', 'вершина', 'дка', 'также', 'терминальный'],
#  ['хотя_один',
#   'вершина',
#   'терминальный',
#   'нка',
#   'соответствовать',
#   'дать',
#   'оно',
#   'лежать',
#   'ранний'],
#  ['каждый', 'состояние'],
#  ['конец'],
#  ['построение',
#   'эквивалентный_дка',
#   'нка',
#   'пусть',
#   'мы',
#   'дать',
#   'произвольный',
#   'нка'],
#  ['построить', 'он', 'следующий', 'дка'],
#  [],
#  [],
#  [],
#  ['доказательство',
#   'эквивалентность',
#   'теорема',
#   'построить',
#   'дка',
#   'эквивалентный',
#   'дать',
#   'нка'],
#  ['доказательство',
#   'доказать',
#   'любой',
#   'слово',
#   'который',
#   'принимать',
#   'нка',
#   'принять',
#   'построить',
#   'дка'],
#  ['заметить',
#   'принимать',
#   'автомат',
#   'нка',
#   'построить',
#   'дка',
#   'принимать',
#   'это',
#   'слово'],
#  ['заметить', 'наблюдение', 'получать', 'образ', 'наш', 'дка', 'принимать'],
#  [],
#  ['рассмотреть', 'слово', 'который'],
#  ['проверить', 'значит', 'исходить', 'наш'],
#  ['далее',
#   'несложно',
#   'заметить',
#   'определение',
#   'терминальный',
#   'состояние',
#   'построить',
#   'дка',
#   'получать'],
#  ['такой',
#   'доказать',
#   'любой',
#   'слово',
#   'который',
#   'принимать',
#   'построить',
#   'дка',
#   'принимать',
#   'нка'],
#  ['сначала',
#   'сделать',
#   'достигнуть',
#   'строка',
#   'наблюдение',
#   'нка',
#   'строка',
#   'существовать_путь',
#   'автомат',
#   'дка',
#   'нка',
#   'принимать',
#   'это',
#   'слово'],
#  ['терминальный', 'состояние', 'значит', 'нка', 'принимать', 'это', 'слово'],
#  ['какой', 'состояние'],
#  ['наш', 'наблюдение', 'нка', 'путь'],
#  ['рассмотреть',
#   'слово',
#   'достигнуть',
#   'который',
#   'принимать',
#   'любой',
#   'строка'],
#  ['проверить',
#   'такой_образ',
#   'множество',
#   'слово',
#   'допускать',
#   'дка',
#   'нка',
#   'совпадать',
#   'эквивалентный'],
#  ['алгоритм_томпсон',
#   'данный',
#   'алгоритм',
#   'преобразовывать',
#   'нка',
#   'эквивалентный_дка'],
#  ['быть',
#   'использовать',
#   'вышеуказанный',
#   'способ',
#   'построение',
#   'один',
#   'дополнение',
#   'быть',
#   'учитывать',
#   'состояние',
#   'недостижимый',
#   'стартовый'],
#  ['поэтому', 'алгоритм', 'использоваться', 'обход', 'ширина'],
#  ['алгоритм',
#   'очередь',
#   'состояние',
#   'соответствующий',
#   'множество',
#   'состоять',
#   'состояние',
#   'нка'],
#  ['массив', 'множество', 'соответствующий', 'состояние', 'дка'],
#  ['стартовый_состояние', 'нка'],
#  ['асимптотик',
#   'количество',
#   'подмножество',
#   'множество',
#   'состояние',
#   'нка',
#   'обрабатывать',
#   'ровно',
#   'время',
#   'получать',
#   'верхний',
#   'оценка',
#   'время_работа_алгоритм',
#   'каждый',
#   'подмножество'],
#  ['пример',
#   'пусть',
#   'мы',
#   'дать',
#   'недетерминированный_конечный',
#   'автомат',
#   'наш',
#   'задание',
#   'эквивалентный_дка',
#   'получать',
#   'множество'],
#  ['мы',
#   'класть',
#   'множество',
#   'помещать',
#   'очередь',
#   'множество',
#   'один',
#   'стартовый_вершина',
#   'очередь',
#   'множество'],
#  [],
#  ['очередь', 'множество', 'мы', 'класть', 'множество'],
#  ['мы', 'класть', 'множество'],
#  ['помечать', 'терминальный', 'вершина', 'данный_случай', 'очередь'],
#  [],
#  [],
#  ['очередь', 'оно'],
#  ['очередь', 'оно'],
#  ['очередь', 'оно'],
#  [],
#  ['итог', 'получать', 'дка', 'эквивалентный_исходный'],
#  ['смотреть'],
#  ['также',
#   'регулярный',
#   'язык',
#   'определение',
#   'эквивалентность',
#   'минимизация_дка',
#   'алгоритм',
#   'построение',
#   'пара',
#   'различимый',
#   'состояние',
#   'теорема_клини',
#   'совпадение_класс',
#   'автоматный',
#   'регулярный',
#   'язык',
#   'источник_информация',
#   'серебряков'],
#  ['теория', 'реализация', 'язык', 'программирование'],
#  ['м', 'мз', 'пресс', 'быть_изд'],
#  ['быть_изд'],
#  [],
#  ['источник'],
#  ['этот_страница', 'последний_отредактировать_сентябрь'],
#  ['автомат', 'переход'],
#  ['замыкание',
#   'содержание',
#   'автомат',
#   'переход',
#   'эквивалентность',
#   'автомат',
#   'переход',
#   'строка',
#   'нка'],
#  ['замыкание',
#   'совпадение',
#   'множество',
#   'язык',
#   'допускать',
#   'нка',
#   'дка',
#   'применение',
#   'смотреть'],
#  ['также_источник_информация',
#   'автомат',
#   'переход',
#   'конечный_автомат',
#   'переход',
#   'конечный_автомат',
#   'который',
#   'возможность',
#   'совершать',
#   'переход'],
#  ['определение', 'нка', 'нка', 'переход', 'англ'],
#  ['набор', 'смысл', 'нка', 'исключение'],
#  ['компонент',
#   'иметь',
#   'эквивалентность',
#   'автомат',
#   'переход',
#   'строка',
#   'нка'],
#  ['замыкание',
#   'быть_называть',
#   'автомат',
#   'эквивалентный',
#   'задавать',
#   'язык'],
#  ['рассмотреть', 'автомат', 'который', 'переход', 'осуществляться', 'строка'],
#  ['это', 'переход', 'вид', 'строка'],
#  ['теорема',
#   'автомат',
#   'переход',
#   'строка',
#   'эквивалентный',
#   'недетерминированный_конечный',
#   'автомат'],
#  ['доказательство',
#   'рассмотреть',
#   'случай',
#   'заменимый',
#   'переход',
#   'такой',
#   'строка',
#   'последовательность',
#   'переход',
#   'символ'],
#  ['именно', 'пусть', 'переход', 'символ'],
#  ['заменимый', 'переход'],
#  ['рассматривать', 'автомат', 'замыкание'],
#  ['определение', 'переход'],
#  ['доказательство',
#   'эквивалентность',
#   'нка',
#   'построить',
#   'замыкание',
#   'англ'],
#  ['построение', 'автомат', 'переход', 'эквивалентный', 'автомат', 'переход'],
#  ['ход',
#   'построение',
#   'замыкание',
#   'транзитивный_замыкание',
#   'подграф',
#   'пусть',
#   'такой_образ',
#   'получить',
#   'автомат',
#   'допускать',
#   'слово',
#   'допускать',
#   'новый',
#   'автомат',
#   'который',
#   'переход'],
#  ['сделать', 'транзитивный_замыкание', 'граф', 'который', 'допускать', 'язык'],
#  ['заметить'],
#  ['совершать', 'два', 'переход', 'подряд'],
#  ['добавление',
#   'допускать',
#   'состояние',
#   'переход',
#   'состояние',
#   'пусть',
#   'текущий',
#   'состояние',
#   'допускать'],
#  ['получить',
#   'автомат',
#   'совершать',
#   'переход',
#   'качество',
#   'последний',
#   'переход'],
#  ['состояние', 'строка', 'закончиться', 'допустить'],
#  ['такой',
#   'случай',
#   'сделать',
#   'обладать',
#   'свойство',
#   'также',
#   'причём',
#   'допускать'],
#  ['добавление',
#   'случай',
#   'получить',
#   'автомат',
#   'добавить',
#   'переход',
#   'допускать',
#   'совершать',
#   'переход'],
#  [],
#  ['заметить',
#   'допускать',
#   'устранение',
#   'переход',
#   'предыдущий',
#   'замечание',
#   'следовать',
#   'устранить',
#   'переход',
#   'допускать',
#   'язык',
#   'измениться'],
#  ['убрать', 'переход'],
#  ['получить', 'нка', 'переход', 'эквивалентный_исходный', 'автомат'],
#  ['совпадение',
#   'множество',
#   'язык',
#   'допускать',
#   'нка',
#   'дка',
#   'утверждение',
#   'множество',
#   'язык',
#   'допускать',
#   'автомат',
#   'переход',
#   'совпадать',
#   'множество',
#   'язык',
#   'допускать',
#   'детерминированный_конечный_автомат'],
#  ['дка'],
#  ['нка'],
#  ['доказать', 'теорема', 'нка', 'нка'],
#  ['значит',
#   'дка',
#   'нка',
#   'применение',
#   'некоторый',
#   'случай',
#   'нка',
#   'переход',
#   'строиться',
#   'простой',
#   'просто',
#   'нка',
#   'дка',
#   'тот',
#   'язык'],
#  ['доказать',
#   'выше',
#   'эквивалентность',
#   'нка',
#   'позволять',
#   'мы',
#   'помощь',
#   'алгоритм',
#   'замыкание',
#   'легко',
#   'приводить',
#   'один',
#   'другой',
#   'далее',
#   'третий'],
#  ['также',
#   'свойство',
#   'доказать',
#   'выше',
#   'являться',
#   'важный',
#   'составлять',
#   'доказательство',
#   'теорема_клини'],
#  ['дка', 'нка', 'смотреть'],
#  ['также',
#   'недетерминированный_конечный',
#   'автомат',
#   'теорема_клини',
#   'совпадение_класс',
#   'автоматный',
#   'регулярный',
#   'язык',
#   'источник_информация',
#   'источник',
#   'переход',
#   'замыкание',
#   'этот_страница',
#   'последний_отредактировать_сентябрь'],
#  ['теорема_клини',
#   'совпадение_класс',
#   'автоматный',
#   'регулярный',
#   'язык',
#   'теорема_клини',
#   'класс_автоматный',
#   'регулярный',
#   'язык',
#   'совпадать'],
#  ['доказательство'],
#  ['доказательство',
#   'быть',
#   'строить',
#   'автомат',
#   'допускать',
#   'регулярный',
#   'язык',
#   'смотреть'],
#  ['картинка', 'справа'],
#  ['быть',
#   'использовать',
#   'индукция',
#   'номер',
#   'поколение',
#   'регулярный',
#   'язык'],
#  ['база', 'достаточно', 'построить', 'автомат', 'три', 'язык'],
#  ['автомат', 'регулярный', 'язык', 'нулевой', 'поколение'],
#  [],
#  [],
#  ['индукционный_переход'],
#  ['уметь',
#   'строить',
#   'автомат',
#   'язык',
#   'достаточно',
#   'научиться',
#   'строить',
#   'автомат',
#   'следующий',
#   'язык',
#   'ого',
#   'поколение'],
#  ['быть', 'строить'],
#  [],
#  [],
#  ['заметить', 'предположение_индукция', 'автомат', 'построить'],
#  ['мочь',
#   'итого',
#   'мочь',
#   'регулярный_выражение',
#   'построить',
#   'автомат',
#   'допускать',
#   'язык'],
#  ['автомат',
#   'объединение',
#   'два',
#   'регулярный',
#   'язык',
#   'автомат',
#   'конкатенация',
#   'два',
#   'регулярный',
#   'язык'],
#  ['автомат',
#   'замыкание_клини',
#   'регулярный',
#   'язык',
#   'доказательство',
#   'быть',
#   'строить',
#   'регулярный_выражение',
#   'допускать',
#   'язык',
#   'задать',
#   'какой',
#   'автомат'],
#  ['пусть', 'задать', 'автомат', 'набор', 'состояние'],
#  ['определимый',
#   'регулярный_выражение',
#   'задавать',
#   'следующий',
#   'множество',
#   'слово',
#   'который',
#   'номер'],
#  ['причём',
#   'качество',
#   'промежуточный',
#   'вершина',
#   'выступать',
#   'такой',
#   'построить',
#   'регулярный_выражение',
#   'символ',
#   'который',
#   'переход',
#   'состояние',
#   'символ',
#   'который',
#   'переход',
#   'состояние',
#   'состояние'],
#  [],
#  [],
#  [],
#  ['сам'],
#  [],
#  [],
#  ['нетрудно', 'задать', 'регулярный_выражение', 'язык', 'исходный', 'автомат'],
#  ['стартовый_состояние',
#   'терминальный',
#   'состояние',
#   'такой_образ',
#   'построить',
#   'автомат',
#   'регулярный_выражение',
#   'допускать',
#   'самый',
#   'язык'],
#  ['смотреть'],
#  ['также',
#   'регулярный',
#   'язык',
#   'определение',
#   'эквивалентность',
#   'детерминированный_конечный_автомат',
#   'источник_информация_википедия',
#   'теорема_клини',
#   'хопкрофт_далее_мотвани_р',
#   'ульман_далее_введение_теория',
#   'автомат',
#   'язык',
#   'вычисление_быть_изд'],
#  ['пер'],
#  ['англ'],
#  ['м_издательский_дом_вильямс'],
#  [],
#  ['источник'],
#  ['этот_страница', 'последний_отредактировать_сентябрь'],
#  ['минимизация_дка',
#   'алгоритм',
#   'построение',
#   'пара',
#   'различимый',
#   'состояние',
#   'задача',
#   'пусть_дать',
#   'автомат',
#   'распознавать',
#   'язык'],
#  [],
#  ['требоваться',
#   'построить',
#   'автомат',
#   'малый',
#   'количество',
#   'состояние',
#   'содержание',
#   'алгоритм',
#   'описание',
#   'корректность',
#   'псевдокод',
#   'асимптотик',
#   'пример',
#   'работа',
#   'шаг',
#   'шаг',
#   'шаг',
#   'шаг',
#   'шаг',
#   'смотреть'],
#  ['также_источник_информация',
#   'алгоритм',
#   'описание',
#   'основный',
#   'идея_алгоритм',
#   'заключаться',
#   'разбить',
#   'состояние',
#   'класс_эквивалентность',
#   'быть',
#   'состояние',
#   'минимизировать',
#   'автомат'],
#  ['реализация',
#   'алгоритм',
#   'мы',
#   'потребоваться',
#   'очередь',
#   'состояние',
#   'автомат'],
#  ['быть',
#   'помечать',
#   'таблица',
#   'пара',
#   'неэквивалентный',
#   'состояние',
#   'класть',
#   'очередь'],
#  ['таблица', 'размер', 'количество'],
#  ['удобно',
#   'увеличить',
#   'номер',
#   'добавить',
#   'исходный',
#   'автомат',
#   'вершина',
#   'состояние',
#   'номер',
#   'который',
#   'быть',
#   'вести',
#   'умолчание',
#   'переход',
#   'исходный',
#   'автомат',
#   'иметь',
#   'состояние',
#   'весь',
#   'символ',
#   'число',
#   'переход',
#   'весь',
#   'символ',
#   'вершина',
#   'сам',
#   'который',
#   'исходный',
#   'автомат',
#   'самый',
#   'увеличить',
#   'количество',
#   'состояние'],
#  ['иметь',
#   'номер',
#   'шаг',
#   'построить',
#   'множество',
#   'шаг',
#   'найти',
#   'достижимый',
#   'состояние',
#   'стартовый'],
#  ['например', 'помощь', 'обход_глубина'],
#  ['пара',
#   'состояние',
#   'различимый',
#   'строка',
#   'шаг',
#   'добавить',
#   'очередь',
#   'пометить',
#   'таблица'],
#  ['шаг', 'каждый', 'непомеченный', 'пара', 'пара', 'нужно', 'проверить'],
#  ['который', 'быть', 'хранить', 'список', 'обратный', 'ребро'],
#  ['пометить'],
#  ['мочь', 'пометить', 'пара'],
#  ['стартовый_состояние',
#   'стать',
#   'пустой',
#   'быть',
#   'делать',
#   'следующий',
#   'пока',
#   'извлечь',
#   'пара',
#   'каждый',
#   'символ',
#   'непомеченный',
#   'пара',
#   'помечать',
#   'таблица',
#   'класть',
#   'очередь'],
#  [],
#  ['перебирать', 'пара', 'состояние'],
#  ['находить',
#   'момент',
#   'опустошение',
#   'очередь',
#   'пара',
#   'состояние',
#   'пометить',
#   'таблица',
#   'являться',
#   'пара',
#   'эквивалентный',
#   'состояние'],
#  ['шаг',
#   'проход',
#   'таблица',
#   'разбивать',
#   'пара',
#   'эквивалентный',
#   'состояние',
#   'класс_эквивалентность'],
#  ['шаг',
#   'проход',
#   'список',
#   'класс_эквивалентность',
#   'выделять',
#   'список',
#   'новый',
#   'состояние',
#   'переход',
#   'они'],
#  ['стартовый_состояние',
#   'получить',
#   'автомат',
#   'состояние',
#   'соответствовать',
#   'класс_эквивалентность',
#   'содержать',
#   'стартовый_состояние',
#   'исходный',
#   'автомат'],
#  ['терминальный',
#   'состояние',
#   'получить',
#   'автомат',
#   'быть',
#   'состояние',
#   'соответствующий',
#   'класс_эквивалентность',
#   'содержать',
#   'терминальный',
#   'состояние',
#   'исходный',
#   'автомат'],
#  ['корректность',
#   'пусть',
#   'результат',
#   'применение',
#   'данный',
#   'алгоритм',
#   'автомат',
#   'автомат',
#   'минимальный',
#   'единственный',
#   'точность',
#   'изоморфизм'],
#  ['получить', 'автомат'],
#  ['доказать', 'пусть', 'существовать', 'автомат', 'состояние', 'строка'],
#  ['итог', 'получить', 'состояние'],
#  ['число',
#   'состояние',
#   'малый',
#   'эквивалентный',
#   'эквивалентный',
#   'такой',
#   'эквивалентный',
#   'допускать',
#   'язык'],
#  ['рассмотреть', 'эквивалентный'],
#  ['значит', 'каждый', 'состояние', 'эквивалентный'],
#  ['аналогично', 'существовать', 'эквивалентный'],
#  [],
#  ['стартовый'],
#  ['пусть',
#   'маленький',
#   'состояние',
#   'состояние',
#   'эквивалентный',
#   'автомат',
#   'противоречие'],
#  ['значит',
#   'два',
#   'состояние',
#   'эквивалентный',
#   'один',
#   'состояние',
#   'построить',
#   'немой',
#   'эквивалентный',
#   'состояние'],
#  [],
#  ['каждый',
#   'состояние',
#   'эквивалентный',
#   'состояние',
#   'автомат',
#   'изоморфный'],
#  ['псевдокод', 'функция', 'построение', 'таблица', 'неэквивалентность'],
#  ['шаг', 'шаг', 'основный', 'функция', 'алгоритм'],
#  ['шаг',
#   'построить',
#   'таблица',
#   'список',
#   'обратный',
#   'ребро',
#   'шаг',
#   'построить',
#   'массив',
#   'достижимость',
#   'состояние',
#   'стартовый',
#   'размер'],
#  ['шаг', 'размер'],
#  ['шаг',
#   'позиция',
#   'быть',
#   'хранить',
#   'номер',
#   'компонент',
#   'эквивалентность',
#   'ого',
#   'состояние'],
#  ['шаг', 'строить', 'требовать', 'автомат'],
#  ['асимптотик',
#   'поиск',
#   'недостижимый',
#   'состояние',
#   'помощь',
#   'обход_глубина',
#   'требовать',
#   'добавлять',
#   'очередь',
#   'значит',
#   'время',
#   'заполнение',
#   'таблица'],
#  ['разбиение_класс', 'эквивалентность', 'время'],
#  ['каждый',
#   'пара',
#   'делаться',
#   'проход',
#   'таблица',
#   'пример',
#   'работа',
#   'минимизировать',
#   'данный',
#   'автомат'],
#  ['шаг', 'строить'],
#  ['например'],
#  ['шаг', 'построить', 'массив', 'достижимость', 'состояние', 'стартовый'],
#  ['шаг', 'инициализировать', 'таблица'],
#  ['вычислить', 'таблица'],
#  ['шаг', 'таблица', 'видно', 'класс', 'эквивалентный', 'состояние', 'это'],
#  ['шаг', 'итого', 'получить', 'автомат', 'смотреть'],
#  ['также',
#   'минимизация_дка',
#   'алгоритм_хопкрофт',
#   'сложность',
#   'источник_информация_хопкрофт_далее',
#   'мотвани_р',
#   'ульман_далее_введение_теория',
#   'автомат',
#   'язык',
#   'вычисление_быть',
#   'издание'],
#  ['пер'],
#  ['англ'],
#  ['м_издательский_дом_вильямс'],
#  [],
#  [],
#  ['источник'],
#  ['этот_страница', 'последний_отредактировать_сентябрь'],
#  ['минимизация_дка',
#   'алгоритм_хопкрофт',
#   'сложность',
#   'пусть_дать',
#   'автомат',
#   'распознавать',
#   'определённый',
#   'язык'],
#  ['требоваться',
#   'найти',
#   'эквивалентный',
#   'автомат',
#   'малый',
#   'количество',
#   'состояние'],
#  ['содержание',
#   'минимизация_дка',
#   'простой',
#   'алгоритм',
#   'псевдокод',
#   'время_работа',
#   'алгоритм_хопкрофт',
#   'реализация',
#   'время_работа',
#   'альтернативный',
#   'реализация',
#   'смотреть'],
#  ['также_источник_информация',
#   'минимизация_дка',
#   'дка',
#   'существовать',
#   'эквивалентный',
#   'состояние',
#   'объединение',
#   'получить',
#   'эквивалентный_дка',
#   'распознавать',
#   'язык',
#   'измениться'],
#  ['основный',
#   'идея',
#   'минимизация',
#   'состоять',
#   'разбиение',
#   'множество',
#   'состояние',
#   'класс_эквивалентность',
#   'получить',
#   'класс',
#   'быть',
#   'состояние',
#   'минимизировать',
#   'дка'],
#  ['простой',
#   'алгоритм',
#   'определение',
#   'класс',
#   'разбивать',
#   'класс',
#   'символ'],
#  [],
#  ['разбитый',
#   'символ',
#   'класс',
#   'существовать',
#   'строка',
#   'который',
#   'различать'],
#  ['класс', 'разбить', 'состоять', 'эквивалентный', 'состояние'],
#  ['поэтому',
#   'самый',
#   'простой',
#   'алгоритм',
#   'состоять',
#   'разбивать',
#   'класс',
#   'текущий_разбиение',
#   'тот_пора',
#   'пока',
#   'это',
#   'возможно'],
#  ['содержать',
#   'хотя_один',
#   'пара',
#   'неэквивалентный',
#   'состояние',
#   'итеративный',
#   'строить',
#   'разбиение',
#   'множество',
#   'состояние',
#   'следующий_образ'],
#  ['первоначальный',
#   'разбиение',
#   'множество',
#   'состояние',
#   'класс',
# ...
#   'дизъюнкция',
#   'дизъюнкция',
#   'конъюнкция',
#   'дизъюнкция',
#   'конъюнкция',
#   'термы',
#   'конъюнкция',
#   'термы_термы',
#   'предикат',
#   'предикат',
#   'аргумент',
#   'аргумент',
#   'переменный',
#   'аргумент',
#   'переменный',
#   'аргумент',
#   'импликация',
#   'конъюнкция',
#   'переменный',
#   'термы',
#   'переменный',
#   'термы',
#   'добавиться',
#   'новый',
#   'сущность',
#   'индивидный',
#   'переменный',
#   'быть',
#   'записывать',
#   'маленький',
#   'латинский_буква',
#   'начало',
#   'алфавит',
#   'предикат',
#   'обобщить',
#   'пропозициональный',
#   'переменный',
#   'существование'],
#  ['квантор', 'всеобщность', 'аксиома', 'определение'],
#  ['быть_говорить',
#   'подстрока',
#   'строка',
#   'являться',
#   'подформула',
#   'точность',
#   'соответствовать',
#   'какой',
#   'один',
#   'нетерминал',
#   'дерево',
#   'дать',
#   'некоторый',
#   'формула',
#   'разбор',
#   'строка'],
#  ['определение',
#   'формула',
#   'входить',
#   'подформула',
#   'получить',
#   'правило',
#   'квантор',
#   'действие',
#   'данный',
#   'квантор',
#   'переменный'],
#  ['также',
#   'быть_говорить',
#   'любой',
#   'подформула',
#   'формула',
#   'быть_говорить',
#   'формула',
#   'находиться',
#   'область',
#   'действие',
#   'данный',
#   'квантор'],
#  ['находиться',
#   'область',
#   'определение',
#   'некоторый',
#   'вхождение',
#   'переменный',
#   'непосредственно',
#   'рядом',
#   'квантор',
#   'свободный'],
#  ['формула',
#   'иметь',
#   'свободный',
#   'вхождение',
#   'переменный',
#   'называться',
#   'замкнутый'],
#  ['находиться',
#   'область',
#   'действие',
#   'квантор',
#   'переменный',
#   'назвать',
#   'связывать'],
#  ['тот',
#   'вхождение',
#   'переменный',
#   'который',
#   'являться',
#   'связанный',
#   'связывать',
#   'назвать',
#   'такой',
#   'вхождение',
#   'назвать',
#   'связанный'],
#  ['вхождение',
#   'переменный',
#   'определение',
#   'быть_говорить',
#   'переменный',
#   'свободный',
#   'вхождение',
#   'один',
#   'вхождение',
#   'стать',
#   'связанный'],
#  ['свободный',
#   'подстановка',
#   'формула',
#   'просто',
#   'свободный',
#   'подстановка',
#   'вместо',
#   'подстановка',
#   'вместо',
#   'получить',
#   'список',
#   'аксиома',
#   'исчисление_предикат',
#   'взять',
#   'схема',
#   'аксиома',
#   'исчисление',
#   'высказывание',
#   'дополнить',
#   'следующий',
#   'два',
#   'схема'],
#  ['переменный', 'пусть', 'вместо', 'свободный', 'вхождение'],
#  ['означать',
#   'результат',
#   'подстановка',
#   'свободно',
#   'подстановка',
#   'вместо',
#   'некоторый',
#   'формула'],
#  ['запись', 'некоторый', 'формула'],
#  ['заметить',
#   'взять',
#   'формула',
#   'тавтология',
#   'схема',
#   'аксиома',
#   'игнорировать',
#   'ограничение',
#   'свобода',
#   'подстановка',
#   'следующий',
#   'утверждение',
#   'должный'],
#  ['однако', 'оно', 'являться'],
#  ['пример',
#   'нарушение',
#   'свобода',
#   'подстановка',
#   'приводить',
#   'противоречие',
#   'предикат',
#   'очевидный',
#   'существовать',
#   'предметный',
#   'множество',
#   'один',
#   'элемент'],
#  ['противоречие',
#   'следовательно',
#   'должный',
#   'свободный',
#   'подстановка',
#   'вместо'],
#  ['аксиома',
#   'породить',
#   'данные',
#   'схема',
#   'новый',
#   'язык',
#   'назвать',
#   'аксиома',
#   'исчисление_предикат'],
#  ['правило', 'вывод', 'пусть', 'входить', 'свободно'],
#  ['рассмотреть',
#   'следующий',
#   'дополнительный',
#   'правило',
#   'вывод',
#   'исчисление_предикат',
#   'добавить',
#   'схема',
#   'схема',
#   'правило',
#   'исчисление',
#   'высказывание',
#   'смочь',
#   'породить',
#   'множество',
#   'правило',
#   'вывод'],
#  ['комментарий', 'входить', 'свободно', 'это', 'также', 'важный', 'вопрос'],
#  ['рассмотреть', 'формула', 'ложный'],
#  ['вывод', 'гипотеза', 'также', 'вполне', 'расширить', 'исчисление_предикат'],
#  ['являться',
#   'общезначимый',
#   'общезначимый',
#   'достаточно',
#   'взять',
#   'качество',
#   'оценка',
#   'свободный',
#   'переменный',
#   'значение',
#   'который'],
#  ['легко', 'показать', 'такой', 'формула', 'общезначимый', 'доказуемый'],
#  ['однако',
#   'итог',
#   'определение',
#   'формальный',
#   'система',
#   'составить',
#   'указанный',
#   'язык',
#   'множество',
#   'аксиома',
#   'множество',
#   'правило',
#   'вывод',
#   'называться',
#   'исчисление_предикат'],
#  ['задание',
#   'оценка',
#   'выражение',
#   'исчисление_предикат',
#   'необходимо',
#   'вместо',
#   'оценка',
#   'переменный',
#   'каждый',
#   'местный',
#   'предикат',
#   'определение',
#   'определить',
#   'функция'],
#  ['исчисление',
#   'высказывание',
#   'ввести',
#   'оценка',
#   'предикат',
#   'формула',
#   'исчисление_предикат',
#   'общезначимый',
#   'истинный',
#   'любой',
#   'предметный',
#   'множество',
#   'индивидный',
#   'переменный'],
#  ['любой',
#   'оценка',
#   'предикат',
#   'любой',
#   'оценка',
#   'свободный',
#   'определение',
#   'пусть',
#   'иметься',
#   'некоторый',
#   'исчисление_предикат',
#   'множество',
#   'аксиома',
#   'пусть_дать',
#   'некоторый',
#   'возможно',
#   'пустой',
#   'список',
#   'назвать',
#   'вывод',
#   'допущение',
#   'предикат'],
#  ['вывод',
#   'формула',
#   'быть',
#   'записывать',
#   'это',
#   'исчисление',
#   'аксиома',
#   'замкнутый',
#   'формула',
#   'исчисление'],
#  ['обратить',
#   'внимание',
#   'требование',
#   'отсутствие',
#   'свободный',
#   'переменный',
#   'допущение'],
#  ['теорема', 'исчисление_предикат', 'корректно', 'так_быть'],
#  ['любой', 'доказуемый', 'утверждение', 'общезначимый'],
#  ['доказательство', 'упражнение'],
#  ['теорема', 'теорема', 'дедукция'],
#  ['доказательство', 'доказательство', 'разбор', 'случай'],
#  ['старый', 'случай', 'тот', 'добавиться', 'новый', 'правило', 'вывод'],
#  ['упражнение'],
#  ['теорема', 'исчисление_предикат', 'полно'],
#  ['доказательство', 'доказательство'],
#  ['источник'],
#  ['этот_страница', 'последний_отредактировать_сентябрь'],
#  ['решение',
#   'уравнение_регулярный_выражение',
#   'содержание',
#   'уравнение_регулярный_выражение',
#   'решение',
#   'уравнение_регулярный_выражение',
#   'решение_система',
#   'уравнение_регулярный_выражение',
#   'пример',
#   'решение_система',
#   'уравнение_регулярный_выражение',
#   'примечание',
#   'смотреть'],
#  ['также_источник_информация',
#   'уравнение_регулярный_выражение',
#   'поскольку',
#   'алгебра',
#   'регулярный_выражение',
#   'являться',
#   'частный',
#   'случаем',
#   'алгебра_клини',
#   'соответствующий',
#   'уравнение',
#   'рассматривать',
#   'уравнение',
#   'алгебра_клини'],
#  ['сам',
#   'этот',
#   'алгебра',
#   'классически',
#   'использоваться',
#   'теория_формальный_язык',
#   'также',
#   'применить',
#   'алгоритм',
#   'поиск',
#   'путь',
#   'граф',
#   'нахождение',
#   'выпуклый',
#   'оболочка'],
#  ['компилятор',
#   'использовать',
#   'доказательство',
#   'корректность',
#   'методика',
#   'оптимизация',
#   'цикл'],
#  ['решение',
#   'уравнение_регулярный_выражение',
#   'пусть',
#   'выражение',
#   'некий',
#   'алфавит',
#   'некий',
#   'язык',
#   'который',
#   'выполняться',
#   'равенство'],
#  ['некий',
#   'регулярный',
#   'утверждение',
#   'пусть',
#   'уравнение',
#   'иметь_вид',
#   'решение',
#   'единственный',
#   'решение',
#   'пусть'],
#  ['начальный', 'равенство', 'выражение', 'следовательно'],
#  [],
#  ['доказать', 'это', 'индукция', 'пусть', 'существовать', 'самый', 'короткий'],
#  ['никакой'],
#  ['короче',
#   'противоречие',
#   'существовать',
#   'сам',
#   'короткий',
#   'значит',
#   'существовать',
#   'пусть',
#   'преобразоваться',
#   'язык'],
#  ['представить', 'язык', 'вид', 'самый', 'любой'],
#  ['заметить', 'далёкий', 'показать', 'отсутствие', 'сам', 'короткий'],
#  [],
#  ['мочь',
#   'взять',
#   'качество',
#   'база',
#   'индукция',
#   'просто',
#   'любой',
#   'исходный',
#   'равенство',
#   'решение_система',
#   'уравнение_регулярный_выражение',
#   'пусть',
#   'система_уравнение',
#   'иметь_вид',
#   'метод',
#   'решение',
#   'выразить',
#   'пусть',
#   'уравнение',
#   'принять',
#   'вид'],
#  ['первый', 'уравнение', 'подставить', 'второе', 'уравнение'],
#  ['решение'],
#  ['подставить', 'следующий', 'уравнение', 'выраженный'],
#  ['далее', 'выполнять', 'схожий', 'итерация', 'получить', 'уравнение'],
#  ['далее', 'подставлять', 'получить', 'ход', 'итерация', 'уравнение', 'найти'],
#  ['обратный',
#   'прогонка',
#   'найти',
#   'пример',
#   'решение_система',
#   'уравнение_регулярный_выражение',
#   'пусть',
#   'мы',
#   'нужно',
#   'найти',
#   'регулярный_выражение',
#   'соответствовать',
#   'язык',
#   'последовательность',
#   'число',
#   'доопределить',
#   'язык',
#   'регулярный_выражение',
#   'сумма',
#   'число',
#   'слово',
#   'равный',
#   'язык',
#   'удовлетворять',
#   'слово',
#   'сумма',
#   'число',
#   'который',
#   'делиться',
#   'модуль',
#   'получить',
#   'система_уравнение',
#   'слово',
#   'который',
#   'интерпретироваться',
#   'поскольку',
#   'мы',
#   'нужно',
#   'найти',
#   'избежать',
#   'обратный',
#   'прогонка',
#   'выражать',
#   'язык'],
#  ['примечание'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['смотреть'],
#  ['также',
#   'альтернативный',
#   'доказательство',
#   'теорема_клини',
#   'система_уравнение',
#   'регулярный_выражение',
#   'источник_информация_википедия',
#   'алгебра_клини',
#   'источник'],
#  ['этот_страница', 'последний_отредактировать_сентябрь'],
#  ['замкнутость_регулярный',
#   'язык',
#   'относительно_различный_операция',
#   'содержание',
#   'теорема',
#   'пример',
#   'доказательство',
#   'гомоморфизм',
#   'цепочка',
#   'язык',
#   'язык',
#   'язык',
#   'смотреть'],
#  ['также_источник',
#   'теорема',
#   'теорема',
#   'пусть',
#   'регулярный',
#   'регулярный',
#   'язык',
#   'один',
#   'алфавит'],
#  ['следующий',
#   'язык',
#   'также',
#   'являться',
#   'язык',
#   'получить',
#   'применение',
#   'следующий',
#   'теоретико',
#   'множественный',
#   'операция'],
#  [],
#  [],
#  ['доказательство',
#   'известно',
#   'класс',
#   'регулярный',
#   'автоматный_язык',
#   'совпадать'],
#  ['пусть', 'язык', 'распознаваться', 'автомат', 'соответственно'],
#  [],
#  [],
#  ['являться', 'регулярный', 'определение', 'регулярный', 'язык'],
#  ['рассмотреть',
#   'автомат',
#   'нетерминальный',
#   'состояние',
#   'инвертировать',
#   'такой',
#   'построение',
#   'следовать',
#   'помнить',
#   'исходный',
#   'автомат',
#   'опустить',
#   'дьявольский',
#   'состояние',
#   'нужно',
#   'явно',
#   'добавить',
#   'сделать',
#   'допускать'],
#  ['очевидный',
#   'допускать',
#   'тот',
#   'тот',
#   'слово',
#   'который',
#   'допускать',
#   'автомат',
#   'автомат',
#   'который',
#   'терминальный',
#   'значит',
#   'язык',
#   'регулярный'],
#  [],
#  ['такой_образ'],
#  ['построить',
#   'явно',
#   'использовать',
#   'конструкция',
#   'произведение',
#   'автомат'],
#  ['регулярный'],
#  [],
#  ['являться', 'регулярный', 'определение', 'регулярный', 'язык'],
#  ['также', 'являться', 'регулярный', 'определение', 'регулярный', 'язык'],
#  ['регулярный'],
#  ['также',
#   'автомат',
#   'пересечение',
#   'язык',
#   'рассмотреть',
#   'нка',
#   'переход',
#   'новый',
#   'автомат',
#   'существовать_путь'],
#  ['исходный',
#   'автомат',
#   'путь',
#   'терминальный',
#   'состояние',
#   'приводить',
#   'терминальный',
#   'состояние'],
#  ['язык', 'наоборот'],
#  ['следовательно', 'регулярный'],
#  ['автомат',
#   'распознать',
#   'точность',
#   'развернуть',
#   'слово',
#   'язык',
#   'пример',
#   'доказательство',
#   'гомоморфизм',
#   'цепочка',
#   'утверждение',
#   'регулярный',
#   'гомоморфизм',
#   'цепочка'],
#  ['регулярный'],
#  ['рассмотреть', 'дка', 'распознавать', 'гомоморфизм'],
#  ['получить',
#   'автомат',
#   'переход',
#   'строка',
#   'распознать',
#   'точность',
#   'эквивалентный_дка'],
#  ['утверждение'],
#  ['заменимый',
#   'немой',
#   'переход',
#   'символ',
#   'переход',
#   'образ',
#   'иметь',
#   'регулярный',
#   'гомоморфизм',
#   'цепочка'],
#  ['регулярный'],
#  ['рассмотреть', 'дка', 'распознавать'],
#  ['отследить',
#   'каждый',
#   'состояние',
#   'положим',
#   'построить',
#   'такой_образ',
#   'функция_переход',
#   'очевидный',
#   'распознать',
#   'слово',
#   'язык',
#   'символ',
#   'строка'],
#  ['новый', 'автомат', 'множество', 'состояние'],
#  ['автомат', 'язык', 'определение', 'определимый'],
#  ['множество',
#   'первый',
#   'половина',
#   'цепочка',
#   'язык',
#   'множество',
#   'например',
#   'длина',
#   'влиять'],
#  [],
#  ['заметить',
#   'цепочка',
#   'нечётный',
#   'утверждение',
#   'пусть',
#   'регулярный',
#   'язык'],
#  ['язык', 'также', 'регулярный'],
#  ['который',
#   'быть',
#   'сконкатенировать',
#   'регулярный',
#   'язык',
#   'существовать',
#   'дка'],
#  ['проверить',
#   'строка',
#   'длина',
#   'обработка',
#   'который',
#   'вести',
#   'состояние'],
#  ['находиться', 'состояние', 'допускать'],
#  ['рассмотреть',
#   'мы',
#   'убедиться',
#   'существовать',
#   'строка',
#   'дать',
#   'строка',
#   'вход',
#   'автомат',
#   'подать'],
#  ['должный',
#   'проверить',
#   'существовать',
#   'строка',
#   'какой',
#   'терминальный',
#   'состояние',
#   'конец',
#   'обработка',
#   'оказаться',
#   'терминальный',
#   'состояние'],
#  ['предположим',
#   'автомат',
#   'закончить',
#   'вершина',
#   'автомат',
#   'предположим',
#   'пройти',
#   'который',
#   'попасть',
#   'терминальный',
#   'отслеживать',
#   'мочь',
#   'построить',
#   'множество',
#   'состояние',
#   'который',
#   'переход',
#   'какой_либо',
#   'состояние',
#   'найти',
#   'способ',
#   'отслеживать',
#   'обновлять',
#   'смочь',
#   'определять',
#   'верно'],
#  ['обозначить', 'множество', 'состояние'],
#  ['смочь'],
#  ['заметить'],
#  ['очевидный', 'единственный', 'символ'],
#  ['шаг'],
#  ['знать'],
#  ['который', 'хранить', 'информация', 'свой', 'состояние'],
#  ['определимый',
#   'это',
#   'пара',
#   'одиночный',
#   'состояние',
#   'множество',
#   'состояние',
#   'автомат',
#   'длина',
#   'определимый',
#   'строка',
#   'перейти',
#   'состояние',
#   'определённый',
#   'выше'],
#  ['вспомнить',
#   'привести',
#   'выше',
#   'функция',
#   'построить',
#   'дка',
#   'каждый',
#   'состояние',
#   'автомат',
#   'переход',
#   'строка',
#   'автомат',
#   'состояние',
#   'состояние',
#   'мочь',
#   'определить',
#   'функция_переход',
#   'следующий_образ',
#   'состояние'],
#  ['множество', 'терминальный', 'состояние'],
#  [],
#  ['функция', 'переслать', 'множество'],
#  ['помощь'],
#  ['начальный',
#   'индукция',
#   'сложно',
#   'доказать',
#   'множество',
#   'терминальный',
#   'вершина',
#   'автомат',
#   'следовательно',
#   'автомат',
#   'язык',
#   'допускать',
#   'язык'],
#  ['следовательно', 'данный', 'язык', 'являться', 'регулярный'],
#  ['допускать',
#   'строка',
#   'такой_образ',
#   'построить',
#   'дка',
#   'который',
#   'допускать'],
#  ['определение'],
#  ['язык',
#   'определение',
#   'определимый',
#   'множество',
#   'цепочка',
#   'представить_вид'],
#  ['например'],
#  ['утверждение', 'пусть', 'регулярный', 'язык'],
#  ['язык', 'также', 'регулярный'],
#  ['который', 'переход', 'регулярный', 'язык', 'существовать'],
#  ['недетерминированный',
#   'автомат',
#   'допускать',
#   'дка',
#   'построить',
#   'переход',
#   'следующий_образ',
#   'рассмотреть',
#   'состояние',
#   'другой',
#   'состояние',
#   'начинать',
#   'построить',
#   'непустой',
#   'слово',
#   'заканчиваться',
#   'терминальный',
#   'вершина'],
#  ['какой',
#   'слово',
#   'проходить',
#   'это',
#   'состояние',
#   'оно',
#   'зацикленный',
#   'такой_образ',
#   'суффикс',
#   'начинаться',
#   'префикс',
#   'заканчиваться',
#   'суффикс'],
#  ['разделить',
#   'автомат',
#   'два',
#   'часть',
#   'содержать',
#   'вершина',
#   'который',
#   'достижимый'],
#  ['заметить',
#   'каждый',
#   'вершина',
#   'содержаться',
#   'оба',
#   'часть',
#   'одновременно',
#   'такой',
#   'случиться',
#   'автомат',
#   'стартовый_вершина',
#   'сделать',
#   'терминальный',
#   'состояние',
#   'помощь',
#   'переход'],
#  ['далее', 'построить', 'содержать', 'цикл'],
#  ['перестроить',
#   'автомат',
#   'принимать',
#   'слово',
#   'зацикленный',
#   'вокруг',
#   'смотреть'],
#  ['рис'],
#  [],
#  ['соединимый', 'достижение', 'терминальный', 'вершина', 'продолжаться'],
#  ['добавить', 'состояние'],
#  ['добавить',
#   'вершина',
#   'построить',
#   'часть',
#   'вершина',
#   'который',
#   'достижимый',
#   'стать',
#   'префикс',
#   'новый',
#   'слово',
#   'начинаться',
#   'рис'],
#  ['разбиение', 'автомат'],
#  ['такой', 'смотреть'],
#  ['рис'],
#  ['часть', 'рис'],
#  ['перестроение'],
#  ['эквивалентный', 'сделать', 'терминальный'],
#  ['данный',
#   'автомат',
#   'принимать',
#   'слово',
#   'зацикленный',
#   'вокруг',
#   'выбрать',
#   'вершина'],
#  ['хотеть',
#   'автомат',
#   'принимать',
#   'слово',
#   'зацикленный',
#   'вокруг',
#   'любой',
#   'создать',
#   'новый_стартовый',
#   'вершина',
#   'связать',
#   'переход',
#   'весь',
#   'перестроить',
#   'автомат',
#   'зацикленный',
#   'вокруг',
#   'подходящий',
#   'построить',
#   'автомат',
#   'допускать',
#   'язык',
#   'следовательно',
#   'данный',
#   'язык',
#   'являться',
#   'регулярный'],
#  ['число', 'изначальный', 'автомат'],
#  [],
#  ['хороший', 'понимание', 'алгоритм', 'рис'],
#  ['автомат',
#   'принимать',
#   'язык',
#   'перестроение',
#   'автомат',
#   'рассмотреть',
#   'пример'],
#  ['рис'],
#  ['представить', 'автомат', 'допускать', 'язык'],
#  ['рис'],
#  ['показать', 'автомат', 'перестроить'],
#  ...]

# %%
model = Word2Vec(vector_size=300, window=7, min_count=3)
model.build_vocab(words)

# %%
model.train(words, total_examples=model.corpus_count, epochs=5)
# Out:
# (211939, 268615)

# %%
model.wv.similarity('слово', 'цепочка')
# Out:
# 0.99979645

# %%
# сохраню потом
model.save('wv_model')

# %%
trigram_transformer.save('wv_trigramm')

# %% [markdown]
# # подвал

# %%
# чистим текст из пдфки
test = make_clean(all_texts[0])

# %%
# словарь с частыми словами
common = get_dict_words(test)

# %%
# словарь с полезными терминами
my_dict = get_useful(common)

# %%
s1 = 'че такое эти ваши производные антимирова'

s2 = 'Как можно вычислить частичные производные Антимирова?'

# %%
my_metrics(s1, s2, trash_dict=trash_dict)
# Out:
# ['такой', 'производный', 'антимиров']
# ['вычислить', 'частичный', 'производный', 'антимиров']
# 0.4998750312421894

# %% [markdown]
# и тут для меня дошло, что, если расписывать вопросы в БЗ, то деление на длину слов вопроса из БЗ (коих будет много) не будет явно и точно отражать близость, но относительно такой штуки можно смотреть динамику
